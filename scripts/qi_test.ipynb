# %%
# !pip install qiskit-quantuminspire
# Out:
# Requirement already satisfied: qiskit-quantuminspire in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (0.16.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit-quantuminspire) (0.4.6)
# Requirement already satisfied: opensquirrel==0.8.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit-quantuminspire) (0.8.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.6 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit-quantuminspire) (2.12.5)
# Collecting qi-compute-api-client<0.57.0,>=0.56.0
#   Using cached qi_compute_api_client-0.56.0-py3-none-any.whl (282 kB)
# Requirement already satisfied: qiskit<2.2.0,>=2.0.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit-quantuminspire) (2.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit-quantuminspire) (2.32.5)
# Requirement already satisfied: libqasm==1.2.1 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from opensquirrel==0.8.0->qiskit-quantuminspire) (1.2.1)
# Requirement already satisfied: networkx>=3.4.2 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from opensquirrel==0.8.0->qiskit-quantuminspire) (3.6.1)
# Requirement already satisfied: numpy>=2.2.6 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from opensquirrel==0.8.0->qiskit-quantuminspire) (2.4.4)
# Requirement already satisfied: scipy>=1.15.3 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from opensquirrel==0.8.0->qiskit-quantuminspire) (1.17.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from pydantic<3.0.0,>=2.10.6->qiskit-quantuminspire) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from pydantic<3.0.0,>=2.10.6->qiskit-quantuminspire) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from pydantic<3.0.0,>=2.10.6->qiskit-quantuminspire) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from pydantic<3.0.0,>=2.10.6->qiskit-quantuminspire) (0.4.2)
# Requirement already satisfied: aiohttp-retry==2.9.1 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (2.9.1)
# Requirement already satisfied: aiohttp==3.13.3 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (3.13.3)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (2.9.0.post0)
# Requirement already satisfied: urllib3==2.6.3 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from requests<3.0.0,>=2.32.3->qiskit-quantuminspire) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from requests<3.0.0,>=2.32.3->qiskit-quantuminspire) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from requests<3.0.0,>=2.32.3->qiskit-quantuminspire) (2026.2.25)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from aiohttp==3.13.3->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from aiohttp==3.13.3->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from aiohttp==3.13.3->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from aiohttp==3.13.3->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from aiohttp==3.13.3->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from aiohttp==3.13.3->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from aiohttp==3.13.3->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (1.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from python-dateutil==2.9.0.post0->qi-compute-api-client<0.57.0,>=0.56.0->qiskit-quantuminspire) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit<2.2.0,>=2.0.0->qiskit-quantuminspire) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit<2.2.0,>=2.0.0->qiskit-quantuminspire) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\cesar\documents\python\master-thesis\master-thesis-rl-qec\.venv\lib\site-packages (from qiskit<2.2.0,>=2.0.0->qiskit-quantuminspire) (5.7.0)
# Installing collected packages: qi-compute-api-client
#   Attempting uninstall: qi-compute-api-client
#     Found existing installation: qi-compute-api-client 0.50.0
#     Uninstalling qi-compute-api-client-0.50.0:
#       Successfully uninstalled qi-compute-api-client-0.50.0
# Successfully installed qi-compute-api-client-0.56.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# quantuminspire 3.5.1 requires qi-compute-api-client<0.51.0,>=0.50.0, but you have qi-compute-api-client 0.56.0 which is incompatible.
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !qi login
# Out:
# It is not necessary to specify the protocol in the URL. The protocol will be determined automatically.
# Please continue logging in by opening: https://auth.quantum-inspire.com/activate?user_code=LRTP-PJPB in your browser
# If promped to verify a code, please confirm it is as follows: LRTP-PJPB
# Login successful!
# Using member ID 2398
# C:\Users\cesar\Documents\Python\master-thesis\Master-thesis-RL-QEC\.venv\Lib\site-packages\pydantic_settings\main.py:452: UserWarning: Config key `json_file` is set in model_config but will be ignored because no JsonConfigSettingsSource source is configured. To use this config key, add a JsonConfigSettingsSource source to the settings sources via the settings_customise_sources hook.
#   cls._settings_warn_unused_config_keys(sources, cls.model_config)

# %%
from qiskit_quantuminspire.qi_provider import QIProvider

provider = QIProvider()

# %%
# Show all current supported backends:
print(provider.backends())
# Out:
# [<qiskit_quantuminspire.qi_backend.QIBackend object at 0x223a8f178d0 (name=QX emulator, id=1)>, <qiskit_quantuminspire.qi_backend.QIBackend object at 0x223a8f17610 (name=Tuna-5, id=4)>, <qiskit_quantuminspire.qi_backend.QIBackend object at 0x223a9445f10 (name=Ry emulator, id=5)>, <qiskit_quantuminspire.qi_backend.QIBackend object at 0x223a952c650 (name=Tuna-9, id=6)>, <qiskit_quantuminspire.qi_backend.QIBackend object at 0x223828a4d10 (name=Tuna-17, id=7)>]

# %%
# Get Quantum Inspire's simulator backend:
simulator_backend = provider.get_backend("QX emulator")

# %%
from qiskit import QuantumCircuit

# Create a basic Bell State circuit:
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

# Show a representation of the quantum circuit:
print(qc)

# Run the circuit on Quantum Inspire's platform:
job = simulator_backend.run(qc)

# Print the results.
result = job.result()
print(result.get_counts())
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1
# {'00': 515, '11': 509}
